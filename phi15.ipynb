# %% [markdown]
# <a href="https://colab.research.google.com/github/vyz1194/GenAI/blob/main/phi15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# !pip install einops
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 22.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 41.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 56.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 60.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 38.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 1.4 MB/s eta 0:00:00
# ...

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

torch.set_default_device("cuda")
model = AutoModelForCausalLM.from_pretrained("microsoft/phi-1_5", trust_remote_code=True)
tokenizer = AutoTokenizer.from_pretrained("microsoft/phi-1_5", trust_remote_code=True)
# Out:
# ...
# A new version of the following files was downloaded from https://huggingface.co/microsoft/phi-1_5:
# - configuration_mixformer_sequential.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ...
# A new version of the following files was downloaded from https://huggingface.co/microsoft/phi-1_5:
# - modeling_mixformer_sequential.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ...
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
inputs = tokenizer('''```python
def print_prime(n):
   """
   Print all primes between 1 and n
   """''', return_tensors="pt", return_attention_mask=False)

outputs = model.generate(**inputs, max_length=200)
text = tokenizer.batch_decode(outputs)[0]
print(text)
# Out:
# ```python
# def print_prime(n):
#    """
#    Print all primes between 1 and n
#    """
#    primes = []
#    for num in range(2, n+1):
#        is_prime = True
#        for i in range(2, int(num**0.5)+1):
#            if num % i == 0:
#                is_prime = False
#                break
#        if is_prime:
#            primes.append(num)
#    print(primes)
#
# print_prime(20)
# ```
#
# ## Exercises
#
# 1. Write a Python function that takes a list of numbers and returns the sum of all even numbers in the list.
#
# ```python
# def sum_even(numbers):
#    """
#    Returns the sum of all even numbers in the list
#    """
#    return sum(num for num in numbers if

# %%
inputs = tokenizer('Plan a 5 day trip to Dubai', return_tensors="pt", return_attention_mask=False)

outputs = model.generate(**inputs, max_length=200)
text = tokenizer.batch_decode(outputs)[0]
print(text)
# Out:
# Plan a 5 day trip to Dubai. You have a budget of $2000. Calculate the maximum amount you can spend per day.
#
# Answer: $2000 / 5 = $400 per day
#
# Exercise 3: You want to buy a new phone that costs $800. You have saved $400 so far. How much more money do you need to save?
#
# Answer: $800 - $400 = $400
#
# Exercise 4: You want to buy a new laptop that costs $1200. You have saved $800 so far. How much more money do you need to save?
#
# Answer: $1200 - $800 = $400
#
# Exercise 5: You want to buy a new car that costs $25,000. You have saved $10,000 so far. How much more money do you need to save?
#
# Answer: $25,000 - $10,000 = $15,000
#
# In conclusion, math

# %%
inputs = tokenizer('Who is Visa Inc', return_tensors="pt", return_attention_mask=False)

outputs = model.generate(**inputs, max_length=200)
text = tokenizer.batch_decode(outputs)[0]
print(text)
# Out:
# Who is Visa Inc. and what is their role in the financial industry?
# Answer: Visa Inc. is a multinational financial services company that provides payment processing services to businesses and individuals worldwide. They are responsible for facilitating transactions and ensuring the smooth flow of money between parties.
#
# Exercise 2: How does the concept of a "bank" relate to the financial industry?
# Answer: A bank is a financial institution that provides various services to individuals and businesses, including savings accounts, loans, and investment opportunities. Banks play a crucial role in the financial industry by acting as intermediaries between savers and borrowers, ensuring the efficient allocation of funds.
#
# Exercise 3: What is the significance of the "cabinet" in the financial industry?
# ...
